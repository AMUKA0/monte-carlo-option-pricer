# %% [markdown]
# # Monte Carlo Option Pricer Demo
#
# Minimal walkthrough using functions from `src/`.

# %%
from src.main import run_report

# Fast demo settings for notebook usage
run_report(S0=100.0, K=110.0, r=0.03, sigma=0.25, T=1.0, n_paths=30000, seed=42)

# %%
from pathlib import Path

fig_dir = Path('results/figures')
sorted(p.name for p in fig_dir.glob('*.png'))
